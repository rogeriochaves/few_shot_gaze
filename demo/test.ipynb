# %%
import pickle
f = open('./rchaves-sofa_calib_target.pkl', 'rb')
targets = pickle.load(f)

# %%
targets
# Out:
# [(93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (93.70833333333334, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (0.0, 22.744444444444444),
#  (-93.57291666666667, 22.744444444444444),
#  (-93.57291666666667, 22.744444444444444),
#  (-93.57291666666667, 22.744444444444444),
#  (-93.57291666666667, 22.744444444444444),
#  (-93.57291666666667, 22.744444444444444),
# ...
